# %% [markdown]
# <a href="https://colab.research.google.com/github/visheshjain392/Processing-image-data/blob/main/Processing_image_data_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Topics:**
#
#
# * Reading an image file and converting it to a numpy array
#
# * Resizing an image
# * RGB to Grayscale conversion

# %%
# getting an image using web get

# !wget 'https://th.bing.com/th/id/OIP.vhp5Kv-azqkBgSp2xogSQAHaE7?w=214&h=180&c=7&r=0&o=5&pid=1.7'
# Out:
# --2025-08-01 04:22:50--  https://th.bing.com/th/id/OIP.vhp5Kv-azqkBgSp2xogSQAHaE7?w=214&h=180&c=7&r=0&o=5&pid=1.7
# Resolving th.bing.com (th.bing.com)... 23.199.34.122, 23.210.215.129, 23.210.215.120, ...
# Connecting to th.bing.com (th.bing.com)|23.199.34.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6823 (6.7K) [image/jpeg]
# Saving to: ‘OIP.vhp5Kv-azqkBgSp2xogSQAHaE7?w=214&h=180&c=7&r=0&o=5&pid=1.7.1’
#
# OIP.vhp5Kv-azqkBgSp 100%[===================>]   6.66K  --.-KB/s    in 0s
#
# 2025-08-01 04:22:50 (96.0 MB/s) - ‘OIP.vhp5Kv-azqkBgSp2xogSQAHaE7?w=214&h=180&c=7&r=0&o=5&pid=1.7.1’ saved [6823/6823]

# %% [markdown]
# **Libraries that can be used for image processing**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (180, 214, 3)

# %%
print(img)
# Out:
# [[[229 230  28]
#   [233 235  30]
#   [237 235  29]
#   ...
#   [173 189   4]
#   [159 174   0]
#   [150 164   0]]
#
#  [[222 225  24]
#   [225 228  25]
#   [229 231  26]
#   ...
#   [164 179   0]
#   [151 165   0]
#   [145 159   0]]
#
#  [[208 216  19]
#   [214 220  22]
#   [219 223  24]
#   ...
#   [154 168   0]
#   [145 158   0]
#   [140 153   0]]
#
#  ...
#
#  [[ 76 113  18]
#   [ 79 116  21]
#   [ 81 121  24]
#   ...
#   [118 111  31]
#   [120 111  32]
#   [121 112  33]]
#
#  [[ 71 108  13]
#   [ 75 112  17]
#   [ 78 118  21]
#   ...
#   [118 111  31]
#   [120 111  32]
#   [121 112  33]]
#
#  [[ 72 109  14]
#   [ 76 113  18]
#   [ 79 119  22]
#   ...
#   [118 111  31]
#   [120 111  32]
#   [121 112  33]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Resizing the image using pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/puppy.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (180, 214, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (180, 214)

# %% [markdown]
# cv2.imshow() will display the immage. But this will not be allowed in Google Colab
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=214x180>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
